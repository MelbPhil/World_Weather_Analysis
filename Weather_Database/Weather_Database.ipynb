# %% [markdown]
# # Generate random coordiantes & random list of cities.

# %%
# Import dependencies.
import numpy as np
import pandas as pd

# %%
# Create random Lats & Lng
lats = np.random.uniform(-90,90, size=2000)
lngs = np.random.uniform(-180,180, size=2000)
lat_lngs = zip(lats,lngs)
coordinates = list(lat_lngs)

# %%
# Import citipy.
from citipy import citipy

# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %% [markdown]
# # Use API to get weather data on list of cities.

# %%
# Import dependencies and weather data key
import sys
sys.path.append('..')
from config import weather_api_key
import requests
import time
from datetime import datetime
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print('Beginning Data Retrieval     ')
print('-----------------------------')

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print(f"{city} not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | brae
# Processing Record 2 of Set 1 | taolanaro
# taolanaro not found. Skipping...
# Processing Record 3 of Set 1 | tsihombe
# tsihombe not found. Skipping...
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | geraldton
# Processing Record 7 of Set 1 | talnakh
# Processing Record 8 of Set 1 | lagoa
# Processing Record 9 of Set 1 | kargil
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | macia
# Processing Record 12 of Set 1 | troitsko-pechorsk
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | ulladulla
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | olafsvik
# Processing Record 17 of Set 1 | kalengwa
# Processing Record 18 of Set 1 | santa isabel do rio negro
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | kiruna
# Processing Record 21 of Set 1 | san andres
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | cockburn town
# Processing Record 24 of Set 1 | marcona
# marcona not found. Skipping...
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | georgetown
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | jaynagar-majilpur
# Processing Record 30 of Set 1 | tura
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | iralaya
# Processing Record 35 of Set 1 | mao
# Processing Record 36 of Set 1 | khasan
# Processing Record 37 of Set 1 | fort saint john
# fort saint john not found. Skipping...
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | gaoua
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | chicama
# Processing Record 42 of Set 1 | barentsburg
# barentsburg not found. Skipping...
# Processing Record 43 of Set 1 | shingu
# Processing Record 44 of Set 1 | dese
# Processing Record 45 of Set 1 | baykit
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | ust-tsilma
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | algodones
# Processing Record 2 of Set 2 | vila franca do campo
# Processing Record 3 of Set 2 | saint-joseph
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | guerrero negro
# Processing Record 6 of Set 2 | votice
# Processing Record 7 of Set 2 | lexington
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | nikolskoye
# Processing Record 10 of Set 2 | alyangula
# Processing Record 11 of Set 2 | umzimvubu
# umzimvubu not found. Skipping...
# Processing Record 12 of Set 2 | veshenskaya
# Processing Record 13 of Set 2 | labytnangi
# Processing Record 14 of Set 2 | pauini
# Processing Record 15 of Set 2 | victoria
# Processing Record 16 of Set 2 | zhuzhou
# Processing Record 17 of Set 2 | mountain home
# Processing Record 18 of Set 2 | inta
# Processing Record 19 of Set 2 | mergui
# mergui not found. Skipping...
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | auki
# Processing Record 22 of Set 2 | shache
# Processing Record 23 of Set 2 | pacifica
# Processing Record 24 of Set 2 | antalaha
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | qaqortoq
# Processing Record 27 of Set 2 | paamiut
# Processing Record 28 of Set 2 | omboue
# Processing Record 29 of Set 2 | raga
# Processing Record 30 of Set 2 | rosetta
# Processing Record 31 of Set 2 | amderma
# amderma not found. Skipping...
# Processing Record 32 of Set 2 | manokwari
# Processing Record 33 of Set 2 | vardo
# Processing Record 34 of Set 2 | bilma
# Processing Record 35 of Set 2 | calca
# Processing Record 36 of Set 2 | yatou
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | san quintin
# Processing Record 39 of Set 2 | chara
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | margate
# Processing Record 42 of Set 2 | nexo
# Processing Record 43 of Set 2 | provideniya
# Processing Record 44 of Set 2 | hami
# Processing Record 45 of Set 2 | emerald
# Processing Record 46 of Set 2 | beachwood
# Processing Record 47 of Set 2 | illoqqortoormiut
# illoqqortoormiut not found. Skipping...
# Processing Record 48 of Set 2 | trairi
# Processing Record 49 of Set 2 | gavle
# Processing Record 50 of Set 2 | eyl
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | warah
# Processing Record 3 of Set 3 | nizhneyansk
# nizhneyansk not found. Skipping...
# Processing Record 4 of Set 3 | meulaboh
# Processing Record 5 of Set 3 | los llanos de aridane
# Processing Record 6 of Set 3 | eldikan
# eldikan not found. Skipping...
# Processing Record 7 of Set 3 | pevek
# Processing Record 8 of Set 3 | opuwo
# Processing Record 9 of Set 3 | port elizabeth
# Processing Record 10 of Set 3 | chokurdakh
# Processing Record 11 of Set 3 | butaritari
# Processing Record 12 of Set 3 | cayenne
# Processing Record 13 of Set 3 | sao joao da barra
# Processing Record 14 of Set 3 | satitoa
# satitoa not found. Skipping...
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | asau
# Processing Record 17 of Set 3 | kokkola
# Processing Record 18 of Set 3 | sentyabrskiy
# sentyabrskiy not found. Skipping...
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | sur
# Processing Record 21 of Set 3 | ornskoldsvik
# Processing Record 22 of Set 3 | srednekolymsk
# Processing Record 23 of Set 3 | superior
# Processing Record 24 of Set 3 | namatanai
# Processing Record 25 of Set 3 | castro
# Processing Record 26 of Set 3 | thunder bay
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | kota kinabalu
# Processing Record 29 of Set 3 | neustrelitz
# Processing Record 30 of Set 3 | tiksi
# Processing Record 31 of Set 3 | belmonte
# Processing Record 32 of Set 3 | yuli
# Processing Record 33 of Set 3 | mys shmidta
# mys shmidta not found. Skipping...
# Processing Record 34 of Set 3 | morlaix
# Processing Record 35 of Set 3 | tabiauea
# tabiauea not found. Skipping...
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | adrar
# Processing Record 38 of Set 3 | phan rang
# phan rang not found. Skipping...
# Processing Record 39 of Set 3 | epe
# Processing Record 40 of Set 3 | belen
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | bredasdorp
# Processing Record 43 of Set 3 | tessalit
# Processing Record 44 of Set 3 | college
# Processing Record 45 of Set 3 | tuatapere
# Processing Record 46 of Set 3 | carnarvon
# Processing Record 47 of Set 3 | hamilton
# Processing Record 48 of Set 3 | hilo
# Processing Record 49 of Set 3 | jhunjhunun
# Processing Record 50 of Set 3 | hermanus
# Processing Record 1 of Set 4 | mattru
# Processing Record 2 of Set 4 | shush
# Processing Record 3 of Set 4 | sedelnikovo
# sedelnikovo not found. Skipping...
# Processing Record 4 of Set 4 | xiuyan
# Processing Record 5 of Set 4 | booue
# Processing Record 6 of Set 4 | aksha
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | port-cartier
# Processing Record 9 of Set 4 | klaksvik
# Processing Record 10 of Set 4 | karratha
# Processing Record 11 of Set 4 | port moresby
# Processing Record 12 of Set 4 | nizwa
# Processing Record 13 of Set 4 | dudinka
# Processing Record 14 of Set 4 | sete
# Processing Record 15 of Set 4 | benguela
# Processing Record 16 of Set 4 | corrientes
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | mount gambier
# Processing Record 19 of Set 4 | hofn
# Processing Record 20 of Set 4 | honiara
# Processing Record 21 of Set 4 | kyren
# Processing Record 22 of Set 4 | pacific grove
# Processing Record 23 of Set 4 | taoudenni
# Processing Record 24 of Set 4 | bonavista
# Processing Record 25 of Set 4 | tual
# Processing Record 26 of Set 4 | hobart
# Processing Record 27 of Set 4 | muros
# Processing Record 28 of Set 4 | sorland
# Processing Record 29 of Set 4 | pala
# Processing Record 30 of Set 4 | ostrovnoy
# Processing Record 31 of Set 4 | voyvozh
# Processing Record 32 of Set 4 | log
# Processing Record 33 of Set 4 | lavrentiya
# Processing Record 34 of Set 4 | middelburg
# Processing Record 35 of Set 4 | dunedin
# Processing Record 36 of Set 4 | ketchikan
# Processing Record 37 of Set 4 | tilichiki
# Processing Record 38 of Set 4 | sao filipe
# Processing Record 39 of Set 4 | gondar
# Processing Record 40 of Set 4 | amahai
# Processing Record 41 of Set 4 | carnot
# Processing Record 42 of Set 4 | lorengau
# Processing Record 43 of Set 4 | kysyl-syr
# Processing Record 44 of Set 4 | hambantota
# Processing Record 45 of Set 4 | kyra
# Processing Record 46 of Set 4 | hithadhoo
# Processing Record 47 of Set 4 | anderson
# Processing Record 48 of Set 4 | namibe
# Processing Record 49 of Set 4 | fortuna
# Processing Record 50 of Set 4 | khandyga
# Processing Record 1 of Set 5 | dalvik
# Processing Record 2 of Set 5 | tulun
# Processing Record 3 of Set 5 | abu dhabi
# Processing Record 4 of Set 5 | pinega
# Processing Record 5 of Set 5 | san cristobal
# Processing Record 6 of Set 5 | saint george
# Processing Record 7 of Set 5 | torbay
# Processing Record 8 of Set 5 | mandalgovi
# Processing Record 9 of Set 5 | ilulissat
# Processing Record 10 of Set 5 | tautira
# Processing Record 11 of Set 5 | faya
# Processing Record 12 of Set 5 | port hardy
# Processing Record 13 of Set 5 | arraial do cabo
# Processing Record 14 of Set 5 | kazalinsk
# kazalinsk not found. Skipping...
# Processing Record 15 of Set 5 | hobyo
# Processing Record 16 of Set 5 | buala
# Processing Record 17 of Set 5 | le port
# Processing Record 18 of Set 5 | cidreira
# Processing Record 19 of Set 5 | kotka
# Processing Record 20 of Set 5 | attawapiskat
# attawapiskat not found. Skipping...
# Processing Record 21 of Set 5 | luderitz
# Processing Record 22 of Set 5 | aswan
# Processing Record 23 of Set 5 | pavlovsk
# Processing Record 24 of Set 5 | cabo san lucas
# Processing Record 25 of Set 5 | sistranda
# Processing Record 26 of Set 5 | ciudad guayana
# Processing Record 27 of Set 5 | beira
# Processing Record 28 of Set 5 | kununurra
# Processing Record 29 of Set 5 | varna
# Processing Record 30 of Set 5 | ngukurr
# ngukurr not found. Skipping...
# Processing Record 31 of Set 5 | pisco
# Processing Record 32 of Set 5 | bethel
# Processing Record 33 of Set 5 | albina
# Processing Record 34 of Set 5 | mount isa
# Processing Record 35 of Set 5 | bontang
# Processing Record 36 of Set 5 | tocache
# Processing Record 37 of Set 5 | kaduqli
# Processing Record 38 of Set 5 | salalah
# Processing Record 39 of Set 5 | nome
# Processing Record 40 of Set 5 | portsmouth
# Processing Record 41 of Set 5 | tateyama
# Processing Record 42 of Set 5 | nuuk
# Processing Record 43 of Set 5 | kamenka
# Processing Record 44 of Set 5 | cherskiy
# Processing Record 45 of Set 5 | yellowknife
# Processing Record 46 of Set 5 | bolungarvik
# bolungarvik not found. Skipping...
# Processing Record 47 of Set 5 | ulaangom
# Processing Record 48 of Set 5 | kuche
# kuche not found. Skipping...
# Processing Record 49 of Set 5 | wulanhaote
# wulanhaote not found. Skipping...
# Processing Record 50 of Set 5 | chandbali
# Processing Record 1 of Set 6 | necochea
# Processing Record 2 of Set 6 | karmana
# karmana not found. Skipping...
# Processing Record 3 of Set 6 | morondava
# Processing Record 4 of Set 6 | panama city
# Processing Record 5 of Set 6 | ilo
# Processing Record 6 of Set 6 | bernay
# Processing Record 7 of Set 6 | port said
# Processing Record 8 of Set 6 | narsaq
# Processing Record 9 of Set 6 | goundam
# Processing Record 10 of Set 6 | new norfolk
# Processing Record 11 of Set 6 | banda aceh
# Processing Record 12 of Set 6 | alcaniz
# Processing Record 13 of Set 6 | yeppoon
# Processing Record 14 of Set 6 | olavarria
# Processing Record 15 of Set 6 | saint-louis
# Processing Record 16 of Set 6 | maniitsoq
# Processing Record 17 of Set 6 | okha
# Processing Record 18 of Set 6 | sabang
# Processing Record 19 of Set 6 | turukhansk
# Processing Record 20 of Set 6 | te anau
# Processing Record 21 of Set 6 | nanortalik
# Processing Record 22 of Set 6 | muli
# Processing Record 23 of Set 6 | norman wells
# Processing Record 24 of Set 6 | constitucion
# Processing Record 25 of Set 6 | warqla
# warqla not found. Skipping...
# Processing Record 26 of Set 6 | san policarpo
# Processing Record 27 of Set 6 | mendoza
# Processing Record 28 of Set 6 | grindavik
# Processing Record 29 of Set 6 | armeria
# Processing Record 30 of Set 6 | port pirie
# Processing Record 31 of Set 6 | abalak
# Processing Record 32 of Set 6 | sipe sipe
# Processing Record 33 of Set 6 | dikson
# Processing Record 34 of Set 6 | itoman
# Processing Record 35 of Set 6 | casablanca
# Processing Record 36 of Set 6 | aklavik
# Processing Record 37 of Set 6 | show low
# Processing Record 38 of Set 6 | vaitupu
# vaitupu not found. Skipping...
# Processing Record 39 of Set 6 | mehamn
# Processing Record 40 of Set 6 | tabou
# Processing Record 41 of Set 6 | ballina
# Processing Record 42 of Set 6 | chaa-khol
# chaa-khol not found. Skipping...
# Processing Record 43 of Set 6 | juterbog
# Processing Record 44 of Set 6 | nam tha
# nam tha not found. Skipping...
# Processing Record 45 of Set 6 | havre-saint-pierre
# Processing Record 46 of Set 6 | nisia floresta
# Processing Record 47 of Set 6 | naze
# Processing Record 48 of Set 6 | pangnirtung
# Processing Record 49 of Set 6 | qasigiannguit
# Processing Record 50 of Set 6 | marystown
# Processing Record 1 of Set 7 | vila
# Processing Record 2 of Set 7 | goure
# Processing Record 3 of Set 7 | vila velha
# Processing Record 4 of Set 7 | polewali
# Processing Record 5 of Set 7 | rakiv lis
# Processing Record 6 of Set 7 | loknya
# Processing Record 7 of Set 7 | ancud
# Processing Record 8 of Set 7 | koungheul
# Processing Record 9 of Set 7 | surt
# Processing Record 10 of Set 7 | severo-kurilsk
# Processing Record 11 of Set 7 | arshan
# Processing Record 12 of Set 7 | bilibino
# Processing Record 13 of Set 7 | codrington
# Processing Record 14 of Set 7 | gorlice
# Processing Record 15 of Set 7 | louisbourg
# louisbourg not found. Skipping...
# Processing Record 16 of Set 7 | longyearbyen
# Processing Record 17 of Set 7 | matay
# Processing Record 18 of Set 7 | yuzhno-yeniseyskiy
# yuzhno-yeniseyskiy not found. Skipping...
# Processing Record 19 of Set 7 | kalat
# Processing Record 20 of Set 7 | capreol
# Processing Record 21 of Set 7 | belaya
# Processing Record 22 of Set 7 | roma
# Processing Record 23 of Set 7 | ust-maya
# Processing Record 24 of Set 7 | saleaula
# saleaula not found. Skipping...
# Processing Record 25 of Set 7 | cabedelo
# Processing Record 26 of Set 7 | fairbanks
# Processing Record 27 of Set 7 | dingle
# Processing Record 28 of Set 7 | nantucket
# Processing Record 29 of Set 7 | khonuu
# khonuu not found. Skipping...
# Processing Record 30 of Set 7 | sitka
# Processing Record 31 of Set 7 | neiafu
# Processing Record 32 of Set 7 | esperance
# Processing Record 33 of Set 7 | ola
# Processing Record 34 of Set 7 | hay river
# Processing Record 35 of Set 7 | iqaluit
# Processing Record 36 of Set 7 | ust-barguzin
# Processing Record 37 of Set 7 | bengkulu
# Processing Record 38 of Set 7 | sioux lookout
# Processing Record 39 of Set 7 | san patricio
# Processing Record 40 of Set 7 | bridgetown
# Processing Record 41 of Set 7 | tabas
# Processing Record 42 of Set 7 | grand-lahou
# Processing Record 43 of Set 7 | reyes
# Processing Record 44 of Set 7 | sebinkarahisar
# Processing Record 45 of Set 7 | barcelos
# Processing Record 46 of Set 7 | tromso
# Processing Record 47 of Set 7 | tyret pervaya
# Processing Record 48 of Set 7 | isangel
# Processing Record 49 of Set 7 | tuggurt
# tuggurt not found. Skipping...
# Processing Record 50 of Set 7 | papetoai
# Processing Record 1 of Set 8 | oranjemund
# Processing Record 2 of Set 8 | pontes e lacerda
# Processing Record 3 of Set 8 | ixtapa
# Processing Record 4 of Set 8 | druzhba
# Processing Record 5 of Set 8 | belushya guba
# belushya guba not found. Skipping...
# Processing Record 6 of Set 8 | durban
# Processing Record 7 of Set 8 | alofi
# Processing Record 8 of Set 8 | mogadishu
# Processing Record 9 of Set 8 | saint-augustin
# Processing Record 10 of Set 8 | eseka
# Processing Record 11 of Set 8 | richards bay
# Processing Record 12 of Set 8 | ha
# ha not found. Skipping...
# Processing Record 13 of Set 8 | alexandria
# Processing Record 14 of Set 8 | haines junction
# Processing Record 15 of Set 8 | bitung
# Processing Record 16 of Set 8 | clyde river
# Processing Record 17 of Set 8 | nizhniy kuranakh
# Processing Record 18 of Set 8 | deniliquin
# Processing Record 19 of Set 8 | sulangan
# Processing Record 20 of Set 8 | kieta
# Processing Record 21 of Set 8 | roald
# Processing Record 22 of Set 8 | souillac
# Processing Record 23 of Set 8 | mayumba
# Processing Record 24 of Set 8 | chornobay
# Processing Record 25 of Set 8 | eskisehir
# Processing Record 26 of Set 8 | chagda
# chagda not found. Skipping...
# Processing Record 27 of Set 8 | zhigansk
# Processing Record 28 of Set 8 | palabuhanratu
# palabuhanratu not found. Skipping...
# Processing Record 29 of Set 8 | hualmay
# Processing Record 30 of Set 8 | rotifunk
# Processing Record 31 of Set 8 | avera
# Processing Record 32 of Set 8 | sibolga
# Processing Record 33 of Set 8 | husavik
# Processing Record 34 of Set 8 | oksfjord
# Processing Record 35 of Set 8 | buritis
# Processing Record 36 of Set 8 | la ronge
# Processing Record 37 of Set 8 | aykhal
# Processing Record 38 of Set 8 | nador
# Processing Record 39 of Set 8 | miraflores
# Processing Record 40 of Set 8 | bangassou
# Processing Record 41 of Set 8 | labuhan
# Processing Record 42 of Set 8 | airai
# Processing Record 43 of Set 8 | santa rosa
# Processing Record 44 of Set 8 | luanda
# Processing Record 45 of Set 8 | santa marinella
# Processing Record 46 of Set 8 | faanui
# Processing Record 47 of Set 8 | fukue
# Processing Record 48 of Set 8 | alta floresta
# Processing Record 49 of Set 8 | broken hill
# Processing Record 50 of Set 8 | trybukhivtsi
# Processing Record 1 of Set 9 | ambanja
# Processing Record 2 of Set 9 | armacao de pera
# Processing Record 3 of Set 9 | nelson bay
# Processing Record 4 of Set 9 | aljezur
# Processing Record 5 of Set 9 | rio tuba
# Processing Record 6 of Set 9 | gigmoto
# Processing Record 7 of Set 9 | aden
# Processing Record 8 of Set 9 | coihaique
# Processing Record 9 of Set 9 | madang
# Processing Record 10 of Set 9 | tabio
# Processing Record 11 of Set 9 | westpunt
# westpunt not found. Skipping...
# Processing Record 12 of Set 9 | vostok
# Processing Record 13 of Set 9 | ginda
# Processing Record 14 of Set 9 | bohmte
# Processing Record 15 of Set 9 | axim
# Processing Record 16 of Set 9 | kui buri
# Processing Record 17 of Set 9 | forio
# Processing Record 18 of Set 9 | beloha
# Processing Record 19 of Set 9 | cap malheureux
# Processing Record 20 of Set 9 | rocha
# Processing Record 21 of Set 9 | mafinga
# Processing Record 22 of Set 9 | yar-sale
# Processing Record 23 of Set 9 | manono
# Processing Record 24 of Set 9 | pennagaram
# Processing Record 25 of Set 9 | inhambane
# Processing Record 26 of Set 9 | samusu
# samusu not found. Skipping...
# Processing Record 27 of Set 9 | havelock
# Processing Record 28 of Set 9 | chuy
# Processing Record 29 of Set 9 | samarai
# Processing Record 30 of Set 9 | ankpa
# Processing Record 31 of Set 9 | rassvet
# Processing Record 32 of Set 9 | cururupu
# Processing Record 33 of Set 9 | bathsheba
# Processing Record 34 of Set 9 | soyo
# Processing Record 35 of Set 9 | aguimes
# Processing Record 36 of Set 9 | nsunga
# Processing Record 37 of Set 9 | ingham
# Processing Record 38 of Set 9 | garowe
# Processing Record 39 of Set 9 | konevo
# Processing Record 40 of Set 9 | byron bay
# Processing Record 41 of Set 9 | bandundu
# Processing Record 42 of Set 9 | toftir
# toftir not found. Skipping...
# Processing Record 43 of Set 9 | khovu-aksy
# Processing Record 44 of Set 9 | merauke
# Processing Record 45 of Set 9 | muswellbrook
# Processing Record 46 of Set 9 | barmer
# Processing Record 47 of Set 9 | luganville
# Processing Record 48 of Set 9 | sechura
# Processing Record 49 of Set 9 | kolokani
# Processing Record 50 of Set 9 | muisne
# Processing Record 1 of Set 10 | maragogi
# Processing Record 2 of Set 10 | sobolevo
# Processing Record 3 of Set 10 | la rioja
# Processing Record 4 of Set 10 | alice springs
# Processing Record 5 of Set 10 | macroom
# Processing Record 6 of Set 10 | high rock
# Processing Record 7 of Set 10 | denpasar
# Processing Record 8 of Set 10 | muscat
# Processing Record 9 of Set 10 | jiuquan
# Processing Record 10 of Set 10 | sao paulo de olivenca
# Processing Record 11 of Set 10 | marovoay
# Processing Record 12 of Set 10 | seddon
# Processing Record 13 of Set 10 | barra do garcas
# Processing Record 14 of Set 10 | mukhen
# Processing Record 15 of Set 10 | rauma
# Processing Record 16 of Set 10 | marawi
# Processing Record 17 of Set 10 | gat
# Processing Record 18 of Set 10 | laguna
# Processing Record 19 of Set 10 | kruisfontein
# Processing Record 20 of Set 10 | cabatuan
# Processing Record 21 of Set 10 | tremedal
# Processing Record 22 of Set 10 | broome
# Processing Record 23 of Set 10 | kikuyu
# Processing Record 24 of Set 10 | timmins
# Processing Record 25 of Set 10 | bakchar
# Processing Record 26 of Set 10 | baruun-urt
# Processing Record 27 of Set 10 | coahuayana
# Processing Record 28 of Set 10 | kostino
# Processing Record 29 of Set 10 | ksenyevka
# ksenyevka not found. Skipping...
# Processing Record 30 of Set 10 | bahia blanca
# Processing Record 31 of Set 10 | smithers
# Processing Record 32 of Set 10 | oreanda
# oreanda not found. Skipping...
# Processing Record 33 of Set 10 | easthampton
# Processing Record 34 of Set 10 | jacareacanga
# Processing Record 35 of Set 10 | solenzo
# Processing Record 36 of Set 10 | malwan
# malwan not found. Skipping...
# Processing Record 37 of Set 10 | millinocket
# Processing Record 38 of Set 10 | nara
# Processing Record 39 of Set 10 | muriwai beach
# Processing Record 40 of Set 10 | henties bay
# Processing Record 41 of Set 10 | bayana
# Processing Record 42 of Set 10 | kashmor
# Processing Record 43 of Set 10 | lolua
# lolua not found. Skipping...
# Processing Record 44 of Set 10 | mahon
# Processing Record 45 of Set 10 | karaton
# Processing Record 46 of Set 10 | guasave
# Processing Record 47 of Set 10 | leningradskiy
# Processing Record 48 of Set 10 | waipawa
# Processing Record 49 of Set 10 | evensk
# Processing Record 50 of Set 10 | kholodnyy
# Processing Record 1 of Set 11 | aller
# Processing Record 2 of Set 11 | tygda
# Processing Record 3 of Set 11 | jiazi
# Processing Record 4 of Set 11 | korla
# Processing Record 5 of Set 11 | logten
# Processing Record 6 of Set 11 | lower hutt
# Processing Record 7 of Set 11 | leoben
# Processing Record 8 of Set 11 | ganzhou
# Processing Record 9 of Set 11 | teguise
# Processing Record 10 of Set 11 | brownsville
# Processing Record 11 of Set 11 | ruwi
# Processing Record 12 of Set 11 | okhotsk
# Processing Record 13 of Set 11 | olga
# Processing Record 14 of Set 11 | beringovskiy
# Processing Record 15 of Set 11 | la plata
# Processing Record 16 of Set 11 | saint anthony
# Processing Record 17 of Set 11 | vao
# Processing Record 18 of Set 11 | tumannyy
# tumannyy not found. Skipping...
# Processing Record 19 of Set 11 | ronne
# Processing Record 20 of Set 11 | kavieng
# Processing Record 21 of Set 11 | trincomalee
# Processing Record 22 of Set 11 | taburi
# taburi not found. Skipping...
# Processing Record 23 of Set 11 | santa barbara
# Processing Record 24 of Set 11 | huilong
# Processing Record 25 of Set 11 | fonte boa
# Processing Record 26 of Set 11 | birjand
# Processing Record 27 of Set 11 | vanimo
# Processing Record 28 of Set 11 | karatau
# Processing Record 29 of Set 11 | tambura
# Processing Record 30 of Set 11 | half moon bay
# Processing Record 31 of Set 11 | takoradi
# Processing Record 32 of Set 11 | sunyani
# Processing Record 33 of Set 11 | caldwell
# Processing Record 34 of Set 11 | svetlogorsk
# Processing Record 35 of Set 11 | padang
# Processing Record 36 of Set 11 | la macarena
# Processing Record 37 of Set 11 | qui nhon
# Processing Record 38 of Set 11 | ondorhaan
# ondorhaan not found. Skipping...
# Processing Record 39 of Set 11 | graaff-reinet
# Processing Record 40 of Set 11 | meadow lake
# Processing Record 41 of Set 11 | myitkyina
# Processing Record 42 of Set 11 | izhma
# Processing Record 43 of Set 11 | hunza
# hunza not found. Skipping...
# Processing Record 44 of Set 11 | sylva
# Processing Record 45 of Set 11 | kenai
# Processing Record 46 of Set 11 | aksu
# Processing Record 47 of Set 11 | kushima
# Processing Record 48 of Set 11 | kongolo
# Processing Record 49 of Set 11 | wilmington
# Processing Record 50 of Set 11 | san borja
# Processing Record 1 of Set 12 | terrace
# Processing Record 2 of Set 12 | yerbogachen
# Processing Record 3 of Set 12 | touros
# Processing Record 4 of Set 12 | port blair
# Processing Record 5 of Set 12 | grand river south east
# grand river south east not found. Skipping...
# Processing Record 6 of Set 12 | aligudarz
# Processing Record 7 of Set 12 | jardim de piranhas
# Processing Record 8 of Set 12 | portland
# Processing Record 9 of Set 12 | thinadhoo
# Processing Record 10 of Set 12 | falkoping
# falkoping not found. Skipping...
# Processing Record 11 of Set 12 | belaya gora
# Processing Record 12 of Set 12 | acapulco
# Processing Record 13 of Set 12 | aquiraz
# Processing Record 14 of Set 12 | chunoyar
# Processing Record 15 of Set 12 | maceio
# Processing Record 16 of Set 12 | aitape
# Processing Record 17 of Set 12 | inuvik
# Processing Record 18 of Set 12 | juba
# Processing Record 19 of Set 12 | solnechnyy
# Processing Record 20 of Set 12 | anadyr
# Processing Record 21 of Set 12 | batemans bay
# Processing Record 22 of Set 12 | qorveh
# Processing Record 23 of Set 12 | ban nahin
# Processing Record 24 of Set 12 | barabinsk
# Processing Record 25 of Set 12 | mayo
# Processing Record 26 of Set 12 | mar del plata
# Processing Record 27 of Set 12 | southbridge
# Processing Record 28 of Set 12 | kloulklubed
# Processing Record 29 of Set 12 | beyneu
# Processing Record 30 of Set 12 | halalo
# halalo not found. Skipping...
# Processing Record 31 of Set 12 | coromandel
# Processing Record 32 of Set 12 | artyk
# artyk not found. Skipping...
# Processing Record 33 of Set 12 | lesnoye
# Processing Record 34 of Set 12 | ambodifototra
# ambodifototra not found. Skipping...
# Processing Record 35 of Set 12 | murud
# Processing Record 36 of Set 12 | alice
# Processing Record 37 of Set 12 | wajima
# Processing Record 38 of Set 12 | kupang
# Processing Record 39 of Set 12 | mugur-aksy
# Processing Record 40 of Set 12 | riberalta
# Processing Record 41 of Set 12 | viligili
# viligili not found. Skipping...
# Processing Record 42 of Set 12 | eureka
# Processing Record 43 of Set 12 | aguas verdes
# Processing Record 44 of Set 12 | sakakah
# Processing Record 45 of Set 12 | port-gentil
# Processing Record 46 of Set 12 | nanfeng
# Processing Record 47 of Set 12 | belle glade
# Processing Record 48 of Set 12 | thohoyandou
# Processing Record 49 of Set 12 | hervey bay
# Processing Record 50 of Set 12 | salamanca
# Processing Record 1 of Set 13 | selizharovo
# Processing Record 2 of Set 13 | khani
# Processing Record 3 of Set 13 | soe
# Processing Record 4 of Set 13 | atambua
# Processing Record 5 of Set 13 | huittinen
# Processing Record 6 of Set 13 | ullapool
# Processing Record 7 of Set 13 | dolbeau
# dolbeau not found. Skipping...
# Processing Record 8 of Set 13 | balsta
# Processing Record 9 of Set 13 | huancabamba
# Processing Record 10 of Set 13 | zhezkazgan
# Processing Record 11 of Set 13 | busca
# Processing Record 12 of Set 13 | jucas
# Processing Record 13 of Set 13 | basco
# Processing Record 14 of Set 13 | zaysan
# Processing Record 15 of Set 13 | cobija
# Processing Record 16 of Set 13 | poso
# Processing Record 17 of Set 13 | talcahuano
# Processing Record 18 of Set 13 | baculin
# Processing Record 19 of Set 13 | pitimbu
# Processing Record 20 of Set 13 | kovrov
# Processing Record 21 of Set 13 | kalaleh
# Processing Record 22 of Set 13 | leh
# Processing Record 23 of Set 13 | carutapera
# Processing Record 24 of Set 13 | uri
# Processing Record 25 of Set 13 | westport
# Processing Record 26 of Set 13 | saldanha
# Processing Record 27 of Set 13 | awbari
# Processing Record 28 of Set 13 | dickinson
# Processing Record 29 of Set 13 | statesboro
# Processing Record 30 of Set 13 | freeport
# Processing Record 31 of Set 13 | tezu
# Processing Record 32 of Set 13 | hailey
# Processing Record 33 of Set 13 | pimentel
# Processing Record 34 of Set 13 | tornio
# Processing Record 35 of Set 13 | loreto
# Processing Record 36 of Set 13 | ust-karsk
# Processing Record 37 of Set 13 | bereznik
# Processing Record 38 of Set 13 | el campo
# Processing Record 39 of Set 13 | hovd
# Processing Record 40 of Set 13 | barranca
# Processing Record 41 of Set 13 | heihe
# Processing Record 42 of Set 13 | kedrovyy
# Processing Record 43 of Set 13 | koupela
# Processing Record 44 of Set 13 | xuddur
# Processing Record 45 of Set 13 | junction city
# Processing Record 46 of Set 13 | la palma
# Processing Record 47 of Set 13 | arlit
# Processing Record 48 of Set 13 | yambio
# Processing Record 49 of Set 13 | luwuk
# Processing Record 50 of Set 13 | juifang
# juifang not found. Skipping...
# Processing Record 1 of Set 14 | wanning
# Processing Record 2 of Set 14 | urdoma
# Processing Record 3 of Set 14 | lander
# Processing Record 4 of Set 14 | big rapids
# Processing Record 5 of Set 14 | porto velho
# Processing Record 6 of Set 14 | puerto montt
# Processing Record 7 of Set 14 | taybad
# Processing Record 8 of Set 14 | bamiantong
# Processing Record 9 of Set 14 | aranos
# Processing Record 10 of Set 14 | nalut
# Processing Record 11 of Set 14 | aksarka
# Processing Record 12 of Set 14 | kiama
# Processing Record 13 of Set 14 | yaan
# Processing Record 14 of Set 14 | port augusta
# Processing Record 15 of Set 14 | kavaratti
# Processing Record 16 of Set 14 | barawe
# barawe not found. Skipping...
# Processing Record 17 of Set 14 | burica
# burica not found. Skipping...
# Processing Record 18 of Set 14 | thanh hoa
# Processing Record 19 of Set 14 | batagay-alyta
# Processing Record 20 of Set 14 | bobonong
# bobonong not found. Skipping...
# Processing Record 21 of Set 14 | kendari
# Processing Record 22 of Set 14 | takhtamygda
# Processing Record 23 of Set 14 | grand gaube
# Processing Record 24 of Set 14 | manaure
# Processing Record 25 of Set 14 | povenets
# Processing Record 26 of Set 14 | pingliang
# Processing Record 27 of Set 14 | terrace bay
# Processing Record 28 of Set 14 | conceicao da barra
# Processing Record 29 of Set 14 | stornoway
# Processing Record 30 of Set 14 | cagayan de tawi-tawi
# cagayan de tawi-tawi not found. Skipping...
# Processing Record 31 of Set 14 | tanete
# Processing Record 32 of Set 14 | xai-xai
# Processing Record 33 of Set 14 | preobrazhenskaya
# preobrazhenskaya not found. Skipping...
# Processing Record 34 of Set 14 | dibaya
# dibaya not found. Skipping...
# Processing Record 35 of Set 14 | kingisepp
# Processing Record 36 of Set 14 | bichura
# Processing Record 37 of Set 14 | greer
# Processing Record 38 of Set 14 | kinablangan
# Processing Record 39 of Set 14 | san angelo
# Processing Record 40 of Set 14 | iguape
# Processing Record 41 of Set 14 | kindu
# Processing Record 42 of Set 14 | bhalki
# Processing Record 43 of Set 14 | kodinsk
# Processing Record 44 of Set 14 | nagato
# Processing Record 45 of Set 14 | berlevag
# Processing Record 46 of Set 14 | makakilo city
# Processing Record 47 of Set 14 | krasnoarmeysk
# Processing Record 48 of Set 14 | ilembula
# Processing Record 49 of Set 14 | bur gabo
# bur gabo not found. Skipping...
# Processing Record 50 of Set 14 | redmond
# Processing Record 1 of Set 15 | maningrida
# Processing Record 2 of Set 15 | jitra
# Processing Record 3 of Set 15 | ankang
# Processing Record 4 of Set 15 | bembereke
# Processing Record 5 of Set 15 | jiwani
# Processing Record 6 of Set 15 | olinda
# Processing Record 7 of Set 15 | sidrolandia
# Processing Record 8 of Set 15 | bad wildungen
# Processing Record 9 of Set 15 | palmas
# Processing Record 10 of Set 15 | shimoda
# Processing Record 11 of Set 15 | flagstaff
# Processing Record 12 of Set 15 | njombe
# Processing Record 13 of Set 15 | matara
# Processing Record 14 of Set 15 | umm lajj
# Processing Record 15 of Set 15 | saint-prosper
# Processing Record 16 of Set 15 | taft
# Processing Record 17 of Set 15 | derzhavinsk
# Processing Record 18 of Set 15 | shelburne
# Processing Record 19 of Set 15 | mirnyy
# Processing Record 20 of Set 15 | yinchuan
# Processing Record 21 of Set 15 | dayong
# Processing Record 22 of Set 15 | chumikan
# Processing Record 23 of Set 15 | praia
# Processing Record 24 of Set 15 | alotau
# alotau not found. Skipping...
# Processing Record 25 of Set 15 | svidnik
# Processing Record 26 of Set 15 | darhan
# Processing Record 27 of Set 15 | afmadu
# afmadu not found. Skipping...
# Processing Record 28 of Set 15 | amapa
# Processing Record 29 of Set 15 | sao jose da coroa grande
# Processing Record 30 of Set 15 | fort nelson
# Processing Record 31 of Set 15 | voh
# Processing Record 32 of Set 15 | novoagansk
# Processing Record 33 of Set 15 | palu
# Processing Record 34 of Set 15 | yining
# Processing Record 35 of Set 15 | karamay
# karamay not found. Skipping...
# Processing Record 36 of Set 15 | villazon
# Processing Record 37 of Set 15 | kusadak
# Processing Record 38 of Set 15 | dong hoi
# Processing Record 39 of Set 15 | martapura
# Processing Record 40 of Set 15 | berbera
# Processing Record 41 of Set 15 | korogwe
# korogwe not found. Skipping...
# Processing Record 42 of Set 15 | mamlyutka
# Processing Record 43 of Set 15 | champerico
# Processing Record 44 of Set 15 | yetholm
# yetholm not found. Skipping...
# Processing Record 45 of Set 15 | pemba
# Processing Record 46 of Set 15 | abu samrah
# Processing Record 47 of Set 15 | salinas
# Processing Record 48 of Set 15 | bom jesus
# Processing Record 49 of Set 15 | mokhsogollokh
# Processing Record 50 of Set 15 | luoyang
# Processing Record 1 of Set 16 | kandi
# Processing Record 2 of Set 16 | spring valley
# Processing Record 3 of Set 16 | utrecht
# Processing Record 4 of Set 16 | rio gallegos
# Processing Record 5 of Set 16 | dandong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries into a Pandas DataFrame and confirm column order.
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Brae      GB  60.3964   -1.3530     50.99        84
# 1       Ponta Do Sol      PT  32.6667  -17.1000     70.00        73
# 2            Rikitea      PF -23.1203 -134.9692     74.82        69
# 3          Geraldton      AU -28.7667  114.6000     50.41        53
# 4            Talnakh      RU  69.4865   88.3972     47.21        65
# 5              Lagoa      PT  39.0500  -27.9833     64.33        68
# 6             Kargil      IN  34.5667   76.1000     63.95        56
# 7           Thompson      CA  55.7435  -97.8558     68.65        27
# 8              Macia      MZ -25.0269   33.0989     62.94        89
# 9  Troitsko-Pechorsk      RU  62.7084   56.1964     51.04        66
#
#    Cloudiness  Wind Speed Current Description
# 0          99       16.49          light rain
# 1          60        3.47       broken clouds
# 2           7        4.32           clear sky
# 3          75       16.11       broken clouds
# 4           7       10.83           clear sky
# 5         100       12.44     overcast clouds
# 6          61        3.27       broken clouds
# 7          90        6.06     overcast clouds
# 8           0        5.17           clear sky
# 9          87        3.85     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = 'WeatherPy_Database.csv'

# Export the City_data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')
